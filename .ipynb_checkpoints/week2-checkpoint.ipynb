# %% [markdown]
# # Matplotlib

# %%
import matplotlib.pyplot as plt 
import numpy as np
# %matplotlib inline

# %%
x=np.arange(0,10)
y=np.arange(11,21)

# %%
#plot scatter
plt.scatter(x,y,c='y')
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.title('2D graph')
# Out:
# Text(0.5, 1.0, '2D graph')

# %%
y=x*x

# %%
#plt plot
plt.plot(x, y, color='green', marker='o', linestyle='dashed')

# %%
#subplot 
plt.subplot(2,2,1)
plt.plot(x,y,'r--')
plt.subplot(2,2,2)
plt.plot(x,y,'b*--')
plt.subplot(2,2,3)
plt.plot(x,y,'go')

# %%
np.pi
# Out:
# 3.141592653589793

# %%
#creating a sin wave 
x=np.arange(0,2* np.pi,0.1)
y=np.sin(x)
plt.title('Sin wave function')
plt.plot(x,y)

# %%
#creating a subplot for sin and cosine function
x=np.arange(0,5* np.pi,0.1)
y_sin=np.sin(x)
y_cos=np.cos(x)
y_tan=np.tan(x)

#for sin funciton


plt.subplot(3,1,1)
plt.plot(x,y_sin,'r*')

plt.title('Sin wave function')
#for cos funciton


plt.subplot(3,1,2)
plt.plot(x,y_cos,'b-')

plt.title('Cos wave function')

#for tan funciton

plt.subplot(3,1,3)
plt.plot(x,y_tan,'g*')

plt.title('tan wave function')
# Out:
# Text(0.5, 1.0, 'tan wave function')

# %%
# Barplot
x=np.array([22,87,5,34,45,67,34,30,20,11,79,31,35,38,28])
plt.hist(x)
plt.title("HISTOGRAM")
# Out:
# Text(0.5, 1.0, 'HISTOGRAM')

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Create a DataFrame
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'Max', 'Dawg'],
    'Age': [25, 30, 35, 25, 30],
    'Salary': [50000, 60000, 70000, 52000, 62000]
}

df = pd.DataFrame(data)
# Bar plot
sns.barplot(x='Name', y='Salary', data=df)
plt.title('Salary by Name')
plt.show()

# %% [markdown]
# # box plot using matplotlib

# %%
data=[np.random.normal(0,std,100)for std in range (1,4)]
# rectangular box plot 
plt.boxplot(data,vert=True,patch_artist=True);

# %% [markdown]
# # Boxplot using Seaborn

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Generate data
data = [np.random.normal(0, std, 100) for std in range(1, 4)]

# Prepare data for Seaborn
# Flatten the data and create corresponding labels
flat_data = [value for sublist in data for value in sublist]
labels = ['Std 1'] * 100 + ['Std 2'] * 100 + ['Std 3'] * 100

# Create a DataFrame for Seaborn
import pandas as pd
df = pd.DataFrame({'Value': flat_data, 'Group': labels})

# Seaborn box plot
sns.boxplot(x='Group', y='Value', data=df, palette='Set3')
plt.title('Seaborn Box Plot')
plt.show()

# %% [markdown]
# # Pie chart

# %%
# pie chart for my income in 2025
x=[200,300,150,250,400]
colors=['red','blue','yellow','green','violet']
labels=['DS','Ytube','Sales','Startup','Sponsor']
explode=(0.1,0.05,0.04,0.03,0.02)
plt.pie(x,labels=labels,colors=colors,explode=explode,shadow=True,autopct='%1.1f%%')
plt.axis('equal')
# Out:
# (-1.1436979629496113,
#  1.1948429143323036,
#  -1.1197635882130061,
#  1.152936971164708)

# %% [markdown]
# # SEABORN IN PYTHON

# %%
import seaborn as sns 
df1=sns.load_dataset("tips")

# %%
df1.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df1
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#now we are using jointplot for this 
df1.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
df1.corr(numeric_only=True)
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
df1.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.heatmap(df1.corr(numeric_only=True))
# Out:
# <Axes: >

# %% [markdown]
# # JointPLot for Univariate Analysis

# %%
sns.jointplot(data=df1,x='tip',y='total_bill',kind='hex')
# Out:
# C:\Users\swora\New folder\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\swora\New folder\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.jointplot(data=df1,x='tip',y='total_bill',kind='reg')
# Out:
# C:\Users\swora\New folder\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\swora\New folder\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# # PAIR PLOT

# %%
#If you've got more than 2 of the variables, then we use pair plot

# %%
sns.pairplot(df1)
# Out:
# C:\Users\swora\New folder\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\swora\New folder\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\swora\New folder\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.pairplot(df1,hue='smoker')
# Out:
# C:\Users\swora\New folder\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\swora\New folder\Lib\site-packages\seaborn\_oldcore.py:1057: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_data = data.groupby(
# C:\Users\swora\New folder\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %% [markdown]
# # Dist plots - used for crerating Histograms

# %%
sns.distplot(df1['tip'],bins=10)
# Out:
# C:\Users\swora\AppData\Local\Temp\ipykernel_32860\2673911472.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df1['tip'],bins=10)
# C:\Users\swora\New folder\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='tip', ylabel='Density'>

# %%
sns.distplot(df1['tip'],kde=False,bins=10)
# Out:
# C:\Users\swora\AppData\Local\Temp\ipykernel_32860\565042169.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df1['tip'],kde=False,bins=10)
# <Axes: xlabel='tip'>

# %%
sns.displot(df1['tip'],kde=False,bins=10)
# Out:
# C:\Users\swora\New folder\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# # Categorical Plots

# %%
# they are used for categorical values and they are of multiple types
# count plot,box plot,violin plot and bar plot

# %%
# 1 ) COUNT PLOT 
sns.countplot(df1,x='day')
# Out:
# C:\Users\swora\New folder\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# <Axes: xlabel='day', ylabel='count'>

# %%
sns.countplot(df1,y='sex')
# Out:
# C:\Users\swora\New folder\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# <Axes: xlabel='count', ylabel='sex'>

# %%
# 2) BAR PLOT
sns.barplot(df1,x="tip",y="sex",hue='smoker')
# Out:
# C:\Users\swora\New folder\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# <Axes: xlabel='tip', ylabel='sex'>

# %%
sns.boxplot(df1,x='sex',y='total_bill')
# Out:
# C:\Users\swora\New folder\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
sns.boxplot(df1,x='total_bill',orient="h")
# Out:
# <Axes: xlabel='total_bill'>

# %%
sns.violinplot(df1,x='sex',y='total_bill',hue='smoker')
# Out:
# C:\Users\swora\New folder\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# <Axes: xlabel='sex', ylabel='total_bill'>

# %% [markdown]
# # Exploratory Data Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
train = pd.read_csv('titanic_train.csv')

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\swora\OneDrive\DS Journey

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# # Missing Data

# %%
# we can use seaborn to create a simple heatmap to see where we are missing the data

# %%
train.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
sns.heatmap(train.isnull(),yticklabels=False,cbar=False,cmap="viridis")
# Out:
# <Axes: >

# %%
sns.distplot(train['Age'].dropna(),kde=False,color='orange')
# Out:
# C:\Users\swora\AppData\Local\Temp\ipykernel_14284\3015411708.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(train['Age'].dropna(),kde=False,color='orange')
# <Axes: xlabel='Age'>

# %% [markdown]
# # Data Cleaning

# %%
# We want to fill in the missing age data instead of just dropping the missing age data rows.One way to do this is by filling in the mean age of all the passengers. However we can be smarter about this and check the average age by passenger class. For example

# %%
train[['Age','Pclass']]
# Out:
#       Age  Pclass
# 0    22.0       3
# 1    38.0       1
# 2    26.0       3
# 3    35.0       1
# 4    35.0       3
# ..    ...     ...
# 886  27.0       2
# 887  19.0       1
# 888   NaN       3
# 889  26.0       1
# 890  32.0       3
#
# [891 rows x 2 columns]

# %%
plt.figure(figsize=(12,7))
sns.boxplot(x="Pclass",y="Age",data=train,palette="winter")
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %%
def impute_age(cols):
    Age =cols[0]
    Pclass=cols[1]
    if pd.isnull(Age):
        if Pclass==1:
            return 37
        elif Pclass==2:
            return 29
        else:
            return 24
    else:
        return Age

# %%
train['Age'] = train[['Age','Pclass']].apply(impute_age,axis=1)
# Out:
# C:\Users\swora\AppData\Local\Temp\ipykernel_14284\1900814082.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   Age =cols[0]
# C:\Users\swora\AppData\Local\Temp\ipykernel_14284\1900814082.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   Pclass=cols[1]

# %%
sns.heatmap(train.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %%
train.drop('Cabin',axis=1,inplace=True)

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   24      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   37      1
# 2                             Heikkinen, Miss. Laina  female   24      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   37      1
# 4                           Allen, Mr. William Henry    male   24      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %%
sns.heatmap(train.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %% [markdown]
# # Converting Categorical Features

# %% [raw]
# We'll need to convert categorical features to dummy variables using Pandas! Machine learning models work with numbers, not text.
#
# Dummy variables transform categories (like "Male" and "Female") into numeric columns (e.g., 1 for Male, 0 for Female) so that models can process and learn from the data.

# %%
pd.get_dummies(train['Embarked'],drop_first=True).head()
# Out:
#        Q      S
# 0  False   True
# 1  False  False
# 2  False   True
# 3  False   True
# 4  False   True

# %% [raw]
# This tells pd.get_dummies() to drop the first category to avoid a problem called dummy variable trap. The dummy variable trap occurs when one category can be predicted from the others, leading to multicollinearity in linear models.

# %%
sex = pd.get_dummies(train['Sex'],drop_first=True)
embark = pd.get_dummies(train['Embarked'],drop_first=True)

# %%
train.drop(['Sex','Embarked','Name','Ticket'],axis=1,inplace=True)

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  Age  SibSp  Parch     Fare
# 0            1         0       3   24      1      0   7.2500
# 1            2         1       1   37      1      0  71.2833
# 2            3         1       3   24      0      0   7.9250
# 3            4         1       1   37      1      0  53.1000
# 4            5         0       3   24      0      0   8.0500

# %%
train =pd.concat([train,sex,embark],axis=1)

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  Age  SibSp  Parch     Fare   male      Q  \
# 0            1         0       3   24      1      0   7.2500   True  False
# 1            2         1       1   37      1      0  71.2833  False  False
# 2            3         1       3   24      0      0   7.9250  False  False
# 3            4         1       1   37      1      0  53.1000  False  False
# 4            5         0       3   24      0      0   8.0500   True  False
#
#        S
# 0   True
# 1  False
# 2   True
# 3   True
# 4   True

# %% [raw]
# List Iterables vs Iterators

# %%
lst=[1,2,243,45,5,7]

# %%
lst1=iter(lst)

# %%
type(lst1)
# Out:
# list_iterator

# %%
next(lst1)
# Out:
# 1

# %% [markdown]
# for i in (lst1):
#     print (i)

# %% [markdown]
# # Python Exception Handling

# %%
try:
    
    ##code block where exception can occur 
    a=b
except Exception as ex:
    
    print(ex)
# Out:
# name 'b' is not defined

# %%
a=b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[80], line 1
# ----> 1 a=b
#
# NameError: name 'b' is not defined

# %%
try:
    a=10
    b=0
    print(a/b)
except Exception as d:
    print(d)
# Out:
# division by zero

# %%
try:
    a=10
    b=0
    print(a/b)
except ZeroDivisionError: 
    print("Please input value other than 0")
# Out:
# Please input value other than 0

# %%
# There is also an else block which shows that if exception isn't being triggered then it shows successful execution
## try else block

try:
    a=int(input("enter a number"))
    b=int(input("enter next number"))
    c=a/b
    d=a*b
except NameError:
    print("Please define the variable")
except TypeError:
    print("Please make same data types")
except ZeroDivisionError:
    print("Enter values other than 0")
except ValueError:
    print("Provide integer value only")
else:
    print(c,d)
# Out:
# enter a number 3
# enter next number s
# Provide integer value only

# %%
### try else finally
# finally block will always get executed 
try:
    a=int(input("enter a number"))
    b=int(input("enter next number"))
    c=a/b
    d=a*b
except NameError:
    print("Please define the variable")
except TypeError:
    print("Please make same data types")
except ZeroDivisionError:
    print("Enter values other than 0")
except ValueError:
    print("Provide integer value only")
else:
    print(c,d)
finally:
    print("The operation is now completed")
# Out:
# enter a number 23
# enter next number 4
# 5.75 92
# The operation is now completed

# %% [markdown]
# # Custom Exception

# %%
class dobException(Error):
    pass

# %%
year=int(input("Enter the year of Birth "))
age=2025-year
try:
    if age<=30 & age>20:
        print("The age is valid. You can apply for the exams")
    else:
        raise dobException
except dobException:
    print("The age is not within the range. You cannot apply for the exams")
# Out:
# Enter the year of Birth  1995
# The age is valid. You can apply for the exams
